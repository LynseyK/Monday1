# %%
# Storage
rooms = {
"Room 1": {
        "description": "This is the Storage Room. Something gleams under one of the strange alien containers - the ignition key! There are doors to the south and the east.",
        "s": "Navigation",
        "e" : "Electrical",
},
# Engine
"Room 2": {
        "description": "You're in what looks like an Engine Room. A massive crystalline reactor pulses with energy. There are doors to the west and the east.",
        
        "w" : "Room 1",
       
        "e" : "Room 3",
},
# Northern Hallway
"Room 3": {
        "description": "desc for Northern Hallway",
        "n" : "Room 2",
        "w" : "Room 7",
        "s": "Room 4",
        "e" : "Room 6",
},# Medbay
"Room 4": {
        "description": "desc for Medbay",
       
        "w" : "Room 5",
       
        
},
# Navigation
"Room 5": {
        "description": "You've discovered the Navigation Room. Panoramic windows offer a breathtaking view of the stars. There is a door to the north and the east.",
        "n" : "Room 4",
        
        "e" : "Room 1",
},
#   Control Room
"Room 6": {
        "description": "This looks like the UFO's Control room. The crystalline ignition key is missing! There is a door to the west and the east.",
        
        "w" : "Room 3",
        
        "e" : "Room 7",
},
# Middle Hallway
"Room 7": {
        "description": "desc for Middle Hallway",
        "n" : "Room 6",
        "w" : "Room 8",
        "s": "Room 9",
        
},
#   Cafeteria
"Room 8": {
        "description": "desc for Cafe",
        
        "e" : " Room 9",
},
# Southern Hallway
"Room 9": {
        "description": "desc for Southern Hallway",
        "n" : "Room 7",
        "w" : "Room 8",
       
},}

# Set the starting room
current_room = "Room 9"
print("Welcome to the UFO Adventure Game!")
print("You've found yourself aboard an alien spacecraft. Find the crystalline ignition key to start the ship!")
print("Type 'quit' to exit the game.")
while True:
    # Print the description of the current room
    print("\n" + rooms[current_room]["description"])
    # Get user input for direction
    direction = input("\nWhich direction do you want to go? (north/east/south/west): ").lower()
    if direction == "quit":
        print("\nThanks for playing! Goodbye!")
        break
    # Check if the direction is valid
    if direction in rooms[current_room]:
        current_room = rooms[current_room][direction]
    else:
        print("\nYou can't go that way! The alien door won't budge.")
# Out:
# Welcome to the UFO Adventure Game!
# You've found yourself aboard an alien spacecraft. Find the crystalline ignition key to start the ship!
# Type 'quit' to exit the game.
#
# desc for Southern Hallway
#
# You can't go that way! The alien door won't budge.
#
# desc for Southern Hallway
#
# desc for Cafe
#
# You can't go that way! The alien door won't budge.
#
# desc for Cafe
#
# Thanks for playing! Goodbye!

# %%
# Define the rooms and their descriptions
rooms = {
    # Storage
    "Room 1": {
            "description": "This is the Storage Room. Something gleams under one of the strange alien containers - the ignition key! There are doors to the south and the east.",
            "s": "Room 5",
            "e" : "Room 2",
    },
    # Engine
    "Room 2": {
            "description": "You're in what looks like an Engine Room. A massive crystalline reactor pulses with energy. There are doors to the west and the east.",
            "w" : "Room 1",
            "e" : "Room 3",
    },
    # Northern Hallway
    "Room 3": {
            "description": "desc for Northern Hallway",
            "n" : "Room 10",
            "w" : "Room 2",
            "s": "Room 7",
            "e" : "Room 4",
    },# Medbay
    "Room 4": {
            "description": "desc for Medbay",
            "w" : "Room 3",
    },
    # Navigation
    "Room 5": {
            "description": "You've discovered the Navigation Room. Panoramic windows offer a breathtaking view of the stars. There is a door to the north and the east.",
            "n" : "Room 1",
            "e" : "Room 6",
    },
    # Control Room
    "Room 6": {
            "description": "This looks like the UFO's Control room. The crystalline ignition key is missing! There is a door to the west and the east.",
            "w" : "Room 5",
            "e" : "Room 7",
    },
    # Middle Hallway
    "Room 7": {
            "description": "desc for Middle Hallway",
            "n" : "Room 3",
            "w" : "Room 6",
            "s": "Room 9",
    },
    # Cafeteria
    "Room 8": {
            "description": "desc for Cafe",
            "e" : "Room 9",
    },
    # Southern Hallway
    "Room 9": {
            "description": "desc for Southern Hallway",
            "n" : "Room 7",
            "w" : "Room 8",
    },
    # Exit
    "Room 10": {
        "description": "Victory Message",
}
}

# Set the starting room
current_room = "Room 9"
print("Welcome to the UFO Adventure Game!")
print("You've found yourself aboard an alien spacecraft. Find the crystalline ignition quitkey to start the ship!")
print("Type 'quit' to exit the game.")
while True:
    # Print the description of the current room
    print("\n" + rooms[current_room]["description"])
    # Get user input for direction
    direction = input("\nWhich direction do you want to go? (n/w/s/e): ").lower()
    if direction == "quit":
        print("\nThanks for playing! Goodbye!")
        break
    # Check if the direction is valid
    if direction in rooms[current_room]:
        current_room = rooms[current_room][direction]
    else:
        print("\nYou can't go that way! There is no path.")
